# %%
#Read all data [194 users' oversampled data]
import csv
import pandas as pd
dataset=pd.read_csv('dataset/AllOversampledNData.csv')
dataset.head()
# Out:
#       F1     F2     F3     F4     F5     F6     F7     F8     F9    F10  ...  \
# 0  0.041  0.026  0.016  0.018  0.060  0.080  0.052  0.049  0.029  0.021  ...
# 1  0.041  0.026  0.016  0.018  0.060  0.080  0.052  0.049  0.029  0.021  ...
# 2  0.040  0.027  0.118  0.068  0.052  0.010  0.021  0.013  0.046  0.064  ...
# 3  0.040  0.027  0.118  0.068  0.052  0.010  0.021  0.013  0.046  0.064  ...
# 4  0.021  0.011  0.006  0.011  0.044  0.022  0.011  0.048  0.047  0.080  ...
#
#      F57    F58    F59    F60    F61    F62  F63    F64    F65              ID
# 0  0.697  0.698  0.698  0.694  0.056  0.039  0.0  0.009  0.043  A3MC5OA9RXOOFH
# 1  0.697  0.698  0.698  0.694  0.056  0.039  0.0  0.009  0.043  A3MC5OA9RXOOFH
# 2  0.677  0.677  0.684  0.684  0.105  0.031  0.0  0.008  0.060  A3MC5OA9RXOOFH
# 3  0.677  0.677  0.684  0.684  0.105  0.031  0.0  0.008  0.060  A3MC5OA9RXOOFH
# 4  0.667  0.667  0.672  0.677  0.067  0.020  1.0  0.014  0.010  A3MC5OA9RXOOFH
#
# [5 rows x 66 columns]

# %%
#replace the user ID by class name and count the number of sample in each class
dataset['ID'] = pd.factorize(dataset['ID'])[0]
dataset.groupby(['ID'])['ID'].count()
# Out:
# ID
# 0      1000
# 1      1000
# 2      1000
# 3      1000
# 4      1000
#        ...
# 188    1000
# 189    1000
# 190    1000
# 191    1000
# 192    1000
# Name: ID, Length: 193, dtype: int64

# %%
#seperate the profile in two groups: (i) Training profile (0-95), and (ii) auxiliary profile (96-193)
totalUser= len(pd.unique(dataset['ID']))
trainingData = dataset[dataset['ID'] < int(totalUser/2)]
auxilaryData = dataset[dataset['ID'] >= int(totalUser/2)]
print("Total user in training dataset:", len(pd.unique(trainingData['ID'])))
print("Total user in auxiliary dataset:", len(pd.unique(auxilaryData['ID'])))
# Out:
# Total user in training dataset: 96
# Total user in auxiliary dataset: 97

# %%
#Seperate the data for model training and attack
import tensorflow
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical


Modeldataset, Attackdataset= train_test_split(trainingData,test_size=0.2, random_state=22)
#ytrain = to_categorical(Modeldataset)
#ytest = to_categorical()
print(Modeldataset.shape)
print(Attackdataset.shape)
# Out:
# (78399, 66)
# (19600, 66)

# %%
#Random project the model dataset
import numpy as np
from sklearn.random_projection import SparseRandomProjection

column1=['RPF1','RPF2','RPF3','RPF4','RPF5','RPF6','RPF7','RPF8','RPF9','RPF10','RPF11','RPF12','RPF13','RPF14','RPF15',
         'RPF16','RPF17','RPF18','RPF19','RPF20','RPF21','RPF22','RPF23','RPF24','RPF25','RPF26','RPF27','RPF28','RPF29','RPF30',
         'RPF31','RPF32','RPF33','RPF34','RPF35','RPF36','RPF37','RPF38','RPF39','RPF40','RPF41','RPF42','RPF43','RPF44','RPF45',
         'RPF46','RPF47','RPF48','RPF49','RPF50','RPF51','RPF52','RPF53','RPF54','RPF55','RPF56','ID']
column2=column1=['RPF1','RPF2','RPF3','RPF4','RPF5','RPF6','RPF7','RPF8','RPF9','RPF10','RPF11','RPF12','RPF13','RPF14','RPF15',
         'RPF16','RPF17','RPF18','RPF19','RPF20','RPF21','RPF22','RPF23','RPF24','RPF25','RPF26','RPF27','RPF28','RPF29','RPF30',
         'RPF31','RPF32','RPF33','RPF34','RPF35','RPF36','RPF37','RPF38','RPF39','RPF40','RPF41','RPF42','RPF43','RPF44','RPF45',
         'RPF46','RPF47','RPF48','RPF49','RPF50','RPF51','RPF52','RPF53','RPF54','RPF55','RPF56']
ModeldatasetRP = pd.DataFrame(columns=column1)
for seed in range(0,96):
    rng = np.random.RandomState(seed)
    X = Modeldataset[Modeldataset['ID']==seed]
    transformer = SparseRandomProjection(n_components=56, random_state=rng)
    Xdata=X.drop(columns=['ID'])
    XRP = pd.DataFrame(transformer.fit_transform(Xdata),columns=column2)
    XRP['ID']=seed
    ModeldatasetRP = pd.concat([ModeldatasetRP, XRP], ignore_index=True)
    #print("Shape of Actual data:",Xdata.shape)
    #print("Shape of Randome Matrix:", transformer.components_.shape[1],transformer.components_.shape[0])
    #print("Shape of Projected data:", X_new.shape)
print(Modeldataset.shape)
print(ModeldatasetRP.shape)
# Out:
# (78399, 66)
# (78399, 57)

# %%
#Prepare the traning data for training and testing the model
import tensorflow
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

X=ModeldatasetRP.drop(columns=['ID'])
y=ModeldatasetRP['ID']

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.1, random_state=22)
Xtrain, Xval, ytrain, yval = train_test_split(Xtrain, ytrain, test_size=0.1, random_state=22)

ytrain = to_categorical(ytrain)
yval = to_categorical(yval)
ytest = to_categorical(ytest)

# %%
print(Xtrain.shape)
print(ytrain.shape)
print(Xval.shape)
print(yval.shape)
print(Xtest.shape)
print(ytest.shape)
# Out:
# (63503, 56)
# (63503, 96)
# (7056, 56)
# (7056, 96)
# (7840, 56)
# (7840, 96)

# %%
# import all necessary package for a neural network
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#matplotlib inlineimport keras
from keras.layers import Dense, Dropout, Input,Activation,Dropout, Flatten
from keras.models import Model,Sequential
from keras.datasets import mnist
#from tqdm import tqdm
#from keras.layers.advanced_activations import LeakyReLU
from keras.layers import BatchNormalization
from keras.optimizers import Adam
#import torch.nn.functional as F

# %%
#define optimizers for neural network
from keras.optimizers import SGD, RMSprop, Adam
def adam_optimizer():
    return Adam(lr=0.0002, beta_1=0.5)

def RMSprop_optimizer():
    return RMSprop(lr=0.001, rho=0.9)

# %%
#neural network architecture for model training

def create_classifierRP(release=False,totalClass=10):
  classifier = Sequential()
  classifier.add(Dense(128, input_dim=56))
  classifier.add(BatchNormalization())
  classifier.add(Activation('relu'))

  #classifier.add(Dense(256))
  #classifier.add(BatchNormalization())
  #classifier.add(Activation('relu'))

  classifier.add(Dense(256))
  classifier.add(BatchNormalization())
  classifier.add(Activation('relu'))

  classifier.add(Dense(256))
  classifier.add(BatchNormalization())
  classifier.add(Activation('relu'))

  #classifier.add(Dense(256))
  #classifier.add(BatchNormalization())
  #classifier.add(Activation('relu'))

  classifier.add(Dense(128))
  classifier.add(BatchNormalization())
  classifier.add(Activation('relu'))

  #if release:
  classifier.add(Dense(totalClass, activation='softmax'))
  #else:
  #   classifier.add(Dense(Tuser))
  #np.log_softmax_v2(a, axis=axis)
  #classifier.add(F.softmax(a, dim=1))

  classifier.compile(loss='categorical_crossentropy', optimizer=RMSprop_optimizer(),metrics=['accuracy'])
  return classifier

Clasf=create_classifierRP()
Clasf.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 128)               7296
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation_8 (Activation)   (None, 128)               0
#
#  dense_11 (Dense)            (None, 256)               33024
#
#  batch_normalization_9 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_9 (Activation)   (None, 256)               0
#
#  dense_12 (Dense)            (None, 256)               65792
#
#  batch_normalization_10 (Bat  (None, 256)              1024
#  chNormalization)
#
#  activation_10 (Activation)  (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  batch_normalization_11 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_11 (Activation)  (None, 128)               0
#
#  dense_14 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 143,370
# Trainable params: 141,834
# Non-trainable params: 1,536
# _________________________________________________________________
# c:\Users\mdmor\OneDrive\Documents\GitHub\ModelDataProtection\.venv\Lib\site-packages\keras\optimizers\legacy\rmsprop.py:143: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
#Train the classifier seperately for black-box attack
import keras

from keras.datasets import mnist
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, UpSampling2D
from keras.optimizers import SGD, RMSprop, Adam
from keras.callbacks import ReduceLROnPlateau


learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', patience=5, verbose=1, factor=0.5,min_lr=0.0001)
callbacks_list = [learning_rate_reduction]

Classfier2= create_classifierRP(True,96)

#------Comment will start from here
lossc='categorical_crossentropy'
optimizerc=RMSprop(lr=0.001, rho=0.9)
Classfier2.compile(loss=lossc, optimizer=optimizerc,metrics=['accuracy'])
#------Comments will end from here
historyc2 =  Classfier2.fit(Xtrain, ytrain, batch_size=64, epochs=50, validation_data=(Xval, yval),verbose=1, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 993/993 [==============================] - ETA: 0s - loss: 0.0680 - accuracy: 0.9945WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 4ms/step - loss: 0.0680 - accuracy: 0.9945 - val_loss: 7.4992e-07 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 2/50
# 979/993 [============================>.] - ETA: 0s - loss: 3.8741e-08 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 3s 3ms/step - loss: 4.1164e-08 - accuracy: 1.0000 - val_loss: 2.0206e-08 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/50
# 988/993 [============================>.] - ETA: 0s - loss: 1.3791e-08 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 3s 3ms/step - loss: 1.4002e-08 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/50
# 992/993 [============================>.] - ETA: 0s - loss: 6.1324e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 7.5520e-09 - accuracy: 1.0000 - val_loss: 4.5447e-09 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/50
# 981/993 [============================>.] - ETA: 0s - loss: 6.5202e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 7.6497e-09 - accuracy: 1.0000 - val_loss: 5.9638e-09 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/50
# 987/993 [============================>.] - ETA: 0s - loss: 3.3926e-07 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 3.4295e-07 - accuracy: 1.0000 - val_loss: 1.0644e-09 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/50
# 985/993 [============================>.] - ETA: 0s - loss: 1.7714e-07 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 1.8024e-07 - accuracy: 1.0000 - val_loss: 1.2671e-08 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 8/50
# 990/993 [============================>.] - ETA: 0s - loss: 5.1909e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 5.3463e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 9/50
# 989/993 [============================>.] - ETA: 0s - loss: 2.2996e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 2.3803e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 10/50
# 991/993 [============================>.] - ETA: 0s - loss: 2.2367e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 2.4836e-09 - accuracy: 1.0000 - val_loss: 1.6895e-11 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 11/50
# 990/993 [============================>.] - ETA: 0s - loss: 2.1336e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 2.5267e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 12/50
# 991/993 [============================>.] - ETA: 0s - loss: 1.9942e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 3.3377e-09 - accuracy: 1.0000 - val_loss: 4.4095e-09 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 13/50
# 982/993 [============================>.] - ETA: 0s - loss: 2.8414e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 2.9247e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 14/50
# 992/993 [============================>.] - ETA: 0s - loss: 2.1030e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 2.1438e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 15/50
# 983/993 [============================>.] - ETA: 0s - loss: 1.5026e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 1.6482e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 16/50
# 987/993 [============================>.] - ETA: 0s - loss: 1.3286e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 1.5093e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 17/50
# 993/993 [==============================] - ETA: 0s - loss: 2.3935e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 2.3935e-09 - accuracy: 1.0000 - val_loss: 1.8584e-10 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 18/50
# 986/993 [============================>.] - ETA: 0s - loss: 2.2839e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 2.3465e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/50
# 989/993 [============================>.] - ETA: 0s - loss: 1.3918e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 2.1888e-09 - accuracy: 1.0000 - val_loss: 4.7305e-10 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 20/50
# 985/993 [============================>.] - ETA: 0s - loss: 2.6190e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 2.8271e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 21/50
# 987/993 [============================>.] - ETA: 0s - loss: 2.0080e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 1.2259e-08 - accuracy: 1.0000 - val_loss: 3.7168e-10 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 22/50
# 987/993 [============================>.] - ETA: 0s - loss: 2.8798e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 3.0073e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 23/50
# 986/993 [============================>.] - ETA: 0s - loss: 1.8834e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 2.1194e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 24/50
# 991/993 [============================>.] - ETA: 0s - loss: 2.6332e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 2.9191e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 25/50
# 989/993 [============================>.] - ETA: 0s - loss: 1.0886e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 1.1789e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 26/50
# 991/993 [============================>.] - ETA: 0s - loss: 1.4285e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 3.4233e-08 - accuracy: 1.0000 - val_loss: 9.6029e-08 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 27/50
# 985/993 [============================>.] - ETA: 0s - loss: 3.7291e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 3.7695e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 28/50
# 990/993 [============================>.] - ETA: 0s - loss: 1.4713e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 1.8172e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 29/50
# 991/993 [============================>.] - ETA: 0s - loss: 1.2743e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 1.4192e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 30/50
# 982/993 [============================>.] - ETA: 0s - loss: 1.4662e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 1.6313e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 31/50
# 980/993 [============================>.] - ETA: 0s - loss: 1.3913e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 3.1368e-09 - accuracy: 1.0000 - val_loss: 5.9132e-10 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 32/50
# 983/993 [============================>.] - ETA: 0s - loss: 1.3700e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 1.5806e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 33/50
# 992/993 [============================>.] - ETA: 0s - loss: 1.0083e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 1.1695e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 34/50
# 981/993 [============================>.] - ETA: 0s - loss: 1.0899e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 1.3084e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 35/50
# 993/993 [==============================] - ETA: 0s - loss: 1.2239e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 1.2239e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 36/50
# 987/993 [============================>.] - ETA: 0s - loss: 8.8697e-10 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 2.8364e-09 - accuracy: 1.0000 - val_loss: 7.7209e-09 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 37/50
# 989/993 [============================>.] - ETA: 0s - loss: 1.7402e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 5ms/step - loss: 1.8941e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 38/50
# 989/993 [============================>.] - ETA: 0s - loss: 1.0095e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 1.0137e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 39/50
# 991/993 [============================>.] - ETA: 0s - loss: 1.4717e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 1.7777e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 40/50
# 992/993 [============================>.] - ETA: 0s - loss: 1.3294e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 1.3741e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 41/50
# 982/993 [============================>.] - ETA: 0s - loss: 1.3790e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 1.4361e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 42/50
# 983/993 [============================>.] - ETA: 0s - loss: 7.8258e-10 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 8.6165e-10 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 43/50
# 988/993 [============================>.] - ETA: 0s - loss: 1.2518e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 1.3065e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 44/50
# 985/993 [============================>.] - ETA: 0s - loss: 1.3975e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 1.9373e-09 - accuracy: 1.0000 - val_loss: 1.6895e-11 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 45/50
# 986/993 [============================>.] - ETA: 0s - loss: 1.2525e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 1.5618e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 46/50
# 988/993 [============================>.] - ETA: 0s - loss: 1.1821e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 1.6820e-09 - accuracy: 1.0000 - val_loss: 1.0137e-10 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 47/50
# 987/993 [============================>.] - ETA: 0s - loss: 1.2399e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 1.2427e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 48/50
# 990/993 [============================>.] - ETA: 0s - loss: 8.6735e-10 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 8.8605e-10 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 49/50
# 985/993 [============================>.] - ETA: 0s - loss: 1.0136e-09 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 5s 5ms/step - loss: 1.2652e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 50/50
# 987/993 [============================>.] - ETA: 0s - loss: 8.2470e-10 - accuracy: 1.0000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 993/993 [==============================] - 4s 4ms/step - loss: 6.4097e-08 - accuracy: 1.0000 - val_loss: 4.1409e-08 - val_accuracy: 1.0000 - lr: 0.0010

# %%
# Plot the classifier loss and accuracy curves for training and validation data
import matplotlib.pyplot as plt
plt.plot(historyc2.history['accuracy'], color='b', label="Training accuracy")
plt.plot(historyc2.history['val_accuracy'], color='r',label="Validation accuracy")
legend = plt.legend(loc='best', shadow=True)
plt.ylabel('accuracy')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
#Performance of the classifier
Classfier2.compile(loss='categorical_crossentropy', optimizer=Adam(),metrics=['accuracy'])
loss, accuracy = Classfier2.evaluate(Xtest, ytest)
#print('Test score:', score)
print('Loss:', loss)
print('Accuracy:', accuracy)
# Out:
# 245/245 [==============================] - 1s 1ms/step - loss: 3.7937e-08 - accuracy: 1.0000
# Loss: 3.793702418875e-08
# Accuracy: 1.0

# %%
#save and load ResNet50MNIST Model
from keras.models import load_model
keras.backend.clear_session()
filename = 'Output/UserModel.h5'
#Classfier2.save(filename)
UserModel=load_model(filename)

# %%
#Random project the Attack dataset
import numpy as np
from sklearn.random_projection import SparseRandomProjection

column1=['RPF1','RPF2','RPF3','RPF4','RPF5','RPF6','RPF7','RPF8','RPF9','RPF10','RPF11','RPF12','RPF13','RPF14','RPF15',
         'RPF16','RPF17','RPF18','RPF19','RPF20','RPF21','RPF22','RPF23','RPF24','RPF25','RPF26','RPF27','RPF28','RPF29','RPF30',
         'RPF31','RPF32','RPF33','RPF34','RPF35','RPF36','RPF37','RPF38','RPF39','RPF40','RPF41','RPF42','RPF43','RPF44','RPF45',
         'RPF46','RPF47','RPF48','RPF49','RPF50','RPF51','RPF52','RPF53','RPF54','RPF55','RPF56','ID']
column2=column1=['RPF1','RPF2','RPF3','RPF4','RPF5','RPF6','RPF7','RPF8','RPF9','RPF10','RPF11','RPF12','RPF13','RPF14','RPF15',
         'RPF16','RPF17','RPF18','RPF19','RPF20','RPF21','RPF22','RPF23','RPF24','RPF25','RPF26','RPF27','RPF28','RPF29','RPF30',
         'RPF31','RPF32','RPF33','RPF34','RPF35','RPF36','RPF37','RPF38','RPF39','RPF40','RPF41','RPF42','RPF43','RPF44','RPF45',
         'RPF46','RPF47','RPF48','RPF49','RPF50','RPF51','RPF52','RPF53','RPF54','RPF55','RPF56']
AttackdatasetRP = pd.DataFrame(columns=column1)
for seed in range(0,96):
    rng = np.random.RandomState(seed+1)
    X = Attackdataset[Attackdataset['ID']==seed]
    transformer = SparseRandomProjection(n_components=56, random_state=rng)
    Xdata=X.drop(columns=['ID'])
    XRP = pd.DataFrame(transformer.fit_transform(Xdata),columns=column2)
    XRP['ID']=seed
    AttackdatasetRP = pd.concat([AttackdatasetRP, XRP], ignore_index=True)
    #print("Shape of Actual data:",Xdata.shape)
    #print("Shape of Randome Matrix:", transformer.components_.shape[1],transformer.components_.shape[0])
    #print("Shape of Projected data:", X_new.shape)
print(Attackdataset.shape)
print(AttackdatasetRP.shape)
# Out:
# (19600, 66)
# (19600, 57)

# %%
#Performance of the classifier
XAttacktest=AttackdatasetRP.drop(columns=['ID'])
yAttacktest=AttackdatasetRP['ID']
yAttacktest=to_categorical(yAttacktest)

#Classfier2.compile(loss='categorical_crossentropy', optimizer=Adam(),metrics=['accuracy'])
loss, accuracy = UserModel.evaluate(XAttacktest, yAttacktest)
#print('Test score:', score)
print('Loss:', loss)
print('Accuracy:', accuracy)
# Out:
# 613/613 [==============================] - 1s 1ms/step - loss: 24.1699 - accuracy: 0.0036
# Loss: 24.16990089416504
# Accuracy: 0.0035714285913854837

# %%
X=AttackdatasetRP.drop(columns=['ID'])
y=AttackdatasetRP['ID']

XUpdate, XUpdatetest, yUpdate, yUpdatetest = train_test_split(X, y, test_size=0.1, random_state=22)
XUpdate, XUpdateval, yUpdate, yUpdateval = train_test_split(XUpdate, yUpdate, test_size=0.1, random_state=22)

yUpdate = to_categorical(yUpdate)
yUpdateval = to_categorical(yUpdateval)
yUpdatetest = to_categorical(yUpdatetest)

# %%
print(XUpdate.shape)
print(yUpdate.shape)
print(XUpdateval.shape)
print(yUpdateval.shape)
print(XUpdatetest.shape)
print(yUpdatetest.shape)
# Out:
# (15876, 56)
# (15876, 96)
# (1764, 56)
# (1764, 96)
# (1960, 56)
# (1960, 96)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', patience=5, verbose=1, factor=0.5,min_lr=0.0001)
callbacks_list = [learning_rate_reduction]

#------Comment will start from here
lossc='categorical_crossentropy'
optimizerc=RMSprop(lr=0.001, rho=0.9)
UserModel.compile(loss=lossc, optimizer=optimizerc,metrics=['accuracy'])
#------Comments will end from here
historyc3=UserModel.fit(XUpdate, yUpdate, batch_size=64, epochs=50, validation_data=(XUpdateval, yUpdateval))
# Out:
# Epoch 1/50
# c:\Users\mdmor\OneDrive\Documents\GitHub\ModelDataProtection\.venv\Lib\site-packages\keras\optimizers\legacy\rmsprop.py:143: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 249/249 [==============================] - 2s 4ms/step - loss: 6.0745e-06 - accuracy: 1.0000 - val_loss: 5.4063e-10 - val_accuracy: 1.0000
# Epoch 2/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.4792e-04 - accuracy: 0.9999 - val_loss: 2.0274e-10 - val_accuracy: 1.0000
# Epoch 3/50
# 249/249 [==============================] - 1s 4ms/step - loss: 4.7770e-04 - accuracy: 0.9999 - val_loss: 5.4063e-10 - val_accuracy: 1.0000
# Epoch 4/50
# 249/249 [==============================] - 1s 4ms/step - loss: 3.2639e-06 - accuracy: 1.0000 - val_loss: 4.0547e-10 - val_accuracy: 1.0000
# Epoch 5/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.1590e-04 - accuracy: 0.9999 - val_loss: 2.4328e-09 - val_accuracy: 1.0000
# Epoch 6/50
# 249/249 [==============================] - 1s 4ms/step - loss: 9.0781e-05 - accuracy: 0.9999 - val_loss: 8.1095e-10 - val_accuracy: 1.0000
# Epoch 7/50
# 249/249 [==============================] - 1s 4ms/step - loss: 6.2483e-06 - accuracy: 1.0000 - val_loss: 5.5415e-09 - val_accuracy: 1.0000
# Epoch 8/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.5096e-06 - accuracy: 1.0000 - val_loss: 6.7579e-10 - val_accuracy: 1.0000
# Epoch 9/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.9847e-07 - accuracy: 1.0000 - val_loss: 1.3516e-10 - val_accuracy: 1.0000
# Epoch 10/50
# 249/249 [==============================] - 1s 4ms/step - loss: 8.9117e-07 - accuracy: 1.0000 - val_loss: 4.7305e-10 - val_accuracy: 1.0000
# Epoch 11/50
# 249/249 [==============================] - 1s 4ms/step - loss: 4.6642e-06 - accuracy: 1.0000 - val_loss: 7.4337e-10 - val_accuracy: 1.0000
# Epoch 12/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.9845e-06 - accuracy: 1.0000 - val_loss: 4.0547e-10 - val_accuracy: 1.0000
# Epoch 13/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.1847e-04 - accuracy: 0.9999 - val_loss: 2.7032e-10 - val_accuracy: 1.0000
# Epoch 14/50
# 249/249 [==============================] - 1s 4ms/step - loss: 3.4934e-06 - accuracy: 1.0000 - val_loss: 2.0274e-10 - val_accuracy: 1.0000
# Epoch 15/50
# 249/249 [==============================] - 1s 4ms/step - loss: 5.9743e-05 - accuracy: 1.0000 - val_loss: 2.7032e-10 - val_accuracy: 1.0000
# Epoch 16/50
# 249/249 [==============================] - 1s 4ms/step - loss: 3.0727e-05 - accuracy: 1.0000 - val_loss: 2.7032e-10 - val_accuracy: 1.0000
# Epoch 17/50
# 249/249 [==============================] - 1s 4ms/step - loss: 4.4491e-04 - accuracy: 0.9999 - val_loss: 2.0274e-10 - val_accuracy: 1.0000
# Epoch 18/50
# 249/249 [==============================] - 1s 4ms/step - loss: 5.7791e-05 - accuracy: 1.0000 - val_loss: 8.1095e-10 - val_accuracy: 1.0000
# Epoch 19/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.6463e-04 - accuracy: 0.9999 - val_loss: 4.0547e-10 - val_accuracy: 1.0000
# Epoch 20/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.2772e-05 - accuracy: 1.0000 - val_loss: 1.7571e-09 - val_accuracy: 1.0000
# Epoch 21/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.0810e-04 - accuracy: 0.9999 - val_loss: 7.4337e-10 - val_accuracy: 1.0000
# Epoch 22/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.5478e-05 - accuracy: 1.0000 - val_loss: 5.4063e-10 - val_accuracy: 1.0000
# Epoch 23/50
# 249/249 [==============================] - 1s 4ms/step - loss: 2.0175e-05 - accuracy: 1.0000 - val_loss: 6.7579e-11 - val_accuracy: 1.0000
# Epoch 24/50
# 249/249 [==============================] - 1s 4ms/step - loss: 3.4246e-04 - accuracy: 0.9999 - val_loss: 2.6356e-09 - val_accuracy: 1.0000
# Epoch 25/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.6504e-06 - accuracy: 1.0000 - val_loss: 4.8657e-09 - val_accuracy: 1.0000
# Epoch 26/50
# 249/249 [==============================] - 1s 4ms/step - loss: 3.3183e-04 - accuracy: 0.9999 - val_loss: 9.4611e-10 - val_accuracy: 1.0000
# Epoch 27/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.0016e-06 - accuracy: 1.0000 - val_loss: 8.7853e-10 - val_accuracy: 1.0000
# Epoch 28/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.0979e-05 - accuracy: 1.0000 - val_loss: 6.8255e-09 - val_accuracy: 1.0000
# Epoch 29/50
# 249/249 [==============================] - 1s 4ms/step - loss: 8.9102e-05 - accuracy: 0.9999 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 30/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.4549e-04 - accuracy: 0.9999 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 31/50
# 249/249 [==============================] - 1s 4ms/step - loss: 7.8887e-06 - accuracy: 1.0000 - val_loss: 2.0274e-10 - val_accuracy: 1.0000
# Epoch 32/50
# 249/249 [==============================] - 1s 4ms/step - loss: 9.0323e-05 - accuracy: 0.9999 - val_loss: 3.3789e-10 - val_accuracy: 1.0000
# Epoch 33/50
# 249/249 [==============================] - 1s 4ms/step - loss: 2.7432e-06 - accuracy: 1.0000 - val_loss: 6.7579e-11 - val_accuracy: 1.0000
# Epoch 34/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.9648e-04 - accuracy: 0.9999 - val_loss: 6.7579e-10 - val_accuracy: 1.0000
# Epoch 35/50
# 249/249 [==============================] - 1s 4ms/step - loss: 4.0562e-05 - accuracy: 1.0000 - val_loss: 4.0547e-10 - val_accuracy: 1.0000
# Epoch 36/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.6340e-06 - accuracy: 1.0000 - val_loss: 6.7579e-10 - val_accuracy: 1.0000
# Epoch 37/50
# 249/249 [==============================] - 1s 4ms/step - loss: 6.0978e-05 - accuracy: 1.0000 - val_loss: 3.3789e-10 - val_accuracy: 1.0000
# Epoch 38/50
# 249/249 [==============================] - 1s 4ms/step - loss: 2.0855e-04 - accuracy: 0.9999 - val_loss: 1.9598e-09 - val_accuracy: 1.0000
# Epoch 39/50
# 249/249 [==============================] - 1s 4ms/step - loss: 7.4591e-06 - accuracy: 1.0000 - val_loss: 1.4192e-09 - val_accuracy: 1.0000
# Epoch 40/50
# 249/249 [==============================] - 1s 4ms/step - loss: 8.5696e-05 - accuracy: 0.9999 - val_loss: 1.0137e-09 - val_accuracy: 1.0000
# Epoch 41/50
# 249/249 [==============================] - 1s 4ms/step - loss: 7.2208e-07 - accuracy: 1.0000 - val_loss: 6.0821e-10 - val_accuracy: 1.0000
# Epoch 42/50
# 249/249 [==============================] - 1s 4ms/step - loss: 3.9221e-05 - accuracy: 1.0000 - val_loss: 1.3516e-10 - val_accuracy: 1.0000
# Epoch 43/50
# 249/249 [==============================] - 1s 4ms/step - loss: 2.2268e-05 - accuracy: 1.0000 - val_loss: 3.2438e-09 - val_accuracy: 1.0000
# Epoch 44/50
# 249/249 [==============================] - 1s 4ms/step - loss: 6.9940e-05 - accuracy: 1.0000 - val_loss: 6.7579e-11 - val_accuracy: 1.0000
# Epoch 45/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.5049e-06 - accuracy: 1.0000 - val_loss: 4.7305e-10 - val_accuracy: 1.0000
# Epoch 46/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.1281e-05 - accuracy: 1.0000 - val_loss: 7.4337e-10 - val_accuracy: 1.0000
# Epoch 47/50
# 249/249 [==============================] - 1s 4ms/step - loss: 7.3891e-04 - accuracy: 0.9999 - val_loss: 1.9598e-09 - val_accuracy: 1.0000
# Epoch 48/50
# 249/249 [==============================] - 1s 4ms/step - loss: 1.3888e-05 - accuracy: 1.0000 - val_loss: 1.4462e-08 - val_accuracy: 1.0000
# Epoch 49/50
# 249/249 [==============================] - 1s 4ms/step - loss: 2.2240e-07 - accuracy: 1.0000 - val_loss: 4.7305e-10 - val_accuracy: 1.0000
# Epoch 50/50
# 249/249 [==============================] - 1s 4ms/step - loss: 2.3530e-06 - accuracy: 1.0000 - val_loss: 1.4192e-09 - val_accuracy: 1.0000

# %%
# Plot the classifier loss and accuracy curves for training and validation data
import matplotlib.pyplot as plt
plt.plot(historyc3.history['accuracy'], color='b', label="Training accuracy")
plt.plot(historyc3.history['val_accuracy'], color='r',label="Validation accuracy")
legend = plt.legend(loc='best', shadow=True)
plt.ylabel('accuracy')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
#Performance of the classifier
#UserModel.compile(loss='categorical_crossentropy', optimizer=Adam(),metrics=['accuracy'])
loss, accuracy = UserModel.evaluate(XUpdatetest, yUpdatetest)
#print('Test score:', score)
print('Loss:', loss)
print('Accuracy:', accuracy)
# Out:
# 62/62 [==============================] - 0s 2ms/step - loss: 1.0138e-07 - accuracy: 1.0000
# Loss: 1.0137951278466062e-07
# Accuracy: 1.0
